# %% [markdown]
# # Customer Segmentation (Clustering)

# %% [markdown]
# Goal: Segment customers based on purchasing behavior.
#
#   What to do:
# Use unsupervised techniques like K-Means or Hierarchical Clustering.
# Group customers based on frequency of purchases, average spend, and product types bought.
# Analyze each segment’s preferences for targeted marketing.
# Why it's useful: Helps you create personalized offers and better target different customer groups.
